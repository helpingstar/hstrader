# %% [markdown]
# # 3분 매매법
# 3분 양봉이 나오면 다음 1분 시작시에 매수하고 1분이 끝날 때 매도하는 방법

# %%
from upbit_quotation import *
FEE = 0.0005

# %% [markdown]
# `from` 시간부터 `to(default=now)` 시간까지의 `unit` 분봉 `DataFrame`을 얻는다.

# %%
df_2022 = get_minute_candle_from_to(1, 'KRW-BTC', '2022-01-01T00:00:00')

# %%
df_2022
# Out:
#         market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0      KRW-BTC  2022-02-02T17:44:00  2022-02-03T02:44:00       46291000
# 1      KRW-BTC  2022-02-02T17:43:00  2022-02-03T02:43:00       46340000
# 2      KRW-BTC  2022-02-02T17:42:00  2022-02-03T02:42:00       46348000
# 3      KRW-BTC  2022-02-02T17:41:00  2022-02-03T02:41:00       46364000
# 4      KRW-BTC  2022-02-02T17:40:00  2022-02-03T02:40:00       46346000
# ...        ...                  ...                  ...            ...
# 47443  KRW-BTC  2021-12-31T15:04:00  2022-01-01T00:04:00       58441000
# 47444  KRW-BTC  2021-12-31T15:03:00  2022-01-01T00:03:00       58423000
# 47445  KRW-BTC  2021-12-31T15:02:00  2022-01-01T00:02:00       58480000
# 47446  KRW-BTC  2021-12-31T15:01:00  2022-01-01T00:01:00       58462000
# 47447  KRW-BTC  2021-12-31T15:00:00  2022-01-01T00:00:00       58412000
#
#        high_price  low_price  trade_price               timestamp  \
# 0        46317000   46280000     46317000 2022-02-02 17:44:23.279
# 1        46348000   46280000     46317000 2022-02-02 17:43:59.762
# 2        46348000   46280000     46300000 2022-02-02 17:42:58.075
# 3        46365000   46346000     46348000 2022-02-02 17:41:59.980
# 4        46365000   46331000     46364000 2022-02-02 17:40:56.907
# ...           ...        ...          ...                     ...
# 47443    58445000   58405000     58435000 2021-12-31 15:04:53.917
# 47444    58442000   58422000     58441000 2021-12-31 15:03:59.557
# 47445    58480000   58405000     58441000 2021-12-31 15:02:58.349
# 47446    58485000   58421000     58480000 2021-12-31 15:02:00.101
# 47447    58477000   58405000     58471000 2021-12-31 15:01:00.079
#
#        candle_acc_trade_price  candle_acc_trade_volume  unit
# 0                2.178948e+07                 0.470559     1
# 1                8.552670e+07                 1.845864     1
# 2                6.875196e+07                 1.484630     1
# 3                2.404063e+07                 0.518585     1
# 4                2.439839e+07                 0.526363     1
# ...                       ...                      ...   ...
# 47443            1.304826e+08                 2.233001     1
# 47444            1.007087e+08                 1.723417     1
# 47445            9.058170e+07                 1.550462     1
# 47446            3.546750e+08                 6.065133     1
# 47447            1.751670e+08                 2.996578     1
#
# [47448 rows x 11 columns]

# %% [markdown]
# 상승이면 `1`, 하강이면 `-1`을 기입하는 Column을 새로 만든다

# %%
df_2022['move'] = np.where(df_2022['opening_price'] < df_2022['trade_price'], 1, -1)

# %%
df_2022
# Out:
#         market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0      KRW-BTC  2022-02-02T17:44:00  2022-02-03T02:44:00       46291000
# 1      KRW-BTC  2022-02-02T17:43:00  2022-02-03T02:43:00       46340000
# 2      KRW-BTC  2022-02-02T17:42:00  2022-02-03T02:42:00       46348000
# 3      KRW-BTC  2022-02-02T17:41:00  2022-02-03T02:41:00       46364000
# 4      KRW-BTC  2022-02-02T17:40:00  2022-02-03T02:40:00       46346000
# ...        ...                  ...                  ...            ...
# 3        46365000   46346000     46348000 2022-02-02 17:41:59.980
# 2        46348000   46280000     46300000 2022-02-02 17:42:58.075
# 1        46348000   46280000     46317000 2022-02-02 17:43:59.762
# 0        46317000   46280000     46317000 2022-02-02 17:44:23.279
#
#        candle_acc_trade_price  candle_acc_trade_volume  unit  move
# 47447            1.751670e+08                 2.996578     1     1
# 47446            3.546750e+08                 6.065133     1     1
# 47445            9.058170e+07                 1.550462     1    -1
# 47444            1.007087e+08                 1.723417     1     1
# 47443            1.304826e+08                 2.233001     1    -1
# ...                       ...                      ...   ...   ...
# 4                2.439839e+07                 0.526363     1     1
# 3                2.404063e+07                 0.518585     1    -1
# 2                6.875196e+07                 1.484630     1    -1
# 1                8.552670e+07                 1.845864     1    -1
# 0                2.178948e+07                 0.470559     1     1
#
# [47448 rows x 12 columns]

# %% [markdown]
# 예산은 `10000`으로 설정하고 `count`가 `3`이 되면 다음 `row`는 무조건 시가에 매수하고 종가에 매도한다, 그리고 `count`는 0으로 만든 후 `continue` 한다

# %%
budget = 10000
count = 0
rise_count = 0
fall_count = 0
result_budget = budget

for _, member in df_2022.iterrows():
    if count == 3:
        result_budget *= 1 - FEE
        result_budget *= (member['trade_price'] / member['opening_price'])
        result_budget *= 1 - FEE
        if member['move'] == 1:
            rise_count += 1
        else:
            fall_count += 1
        count = 0
        continue
    if member['move'] == 1:
        count += 1
    if member['move'] == -1:
        count = 0

# %% [markdown]
# 수익률 **-93.14%**, 무조건 망하니 생각도 하지 말자

# %%
pd.DataFrame({'year': [2022], 'budget': [result_budget], 'rise_count': [rise_count], 'fall_count': [fall_count], 'earnings rate': [(result_budget / budget) - 1]}).set_index('year')
# Out:
#           budget  rise_count  fall_count  earnings rate
# year
# 2022  685.031461        1372        1416      -0.931497

# %% [markdown]
# 위의 과정을 함수화 하여 다른 연도에도 적용해보자

# %%
df_2021 = get_minute_candle_from_to(1, 'KRW-BTC', start='2021-01-01T00:00:00', end='2022-01-01T00:00:00')
df_2020 = get_minute_candle_from_to(1, 'KRW-BTC', start='2020-01-01T00:00:00', end='2021-01-01T00:00:00')

# %%
def m3_strategy_info(df, budget, year):
    df['move'] = np.where(df['opening_price'] < df['trade_price'], 1, -1)
    df = df[::-1]
    count = 0
    rise_count = 0
    fall_count = 0
    result_budget = budget

    for _, member in df.iterrows():
        if count == 3:
            result_budget *= 1 - FEE
            result_budget *= (member['trade_price'] / member['opening_price'])
            result_budget *= 1 - FEE
            if member['move'] == 1:
                rise_count += 1
            else:
                fall_count += 1
            count = 0
            continue
        if member['move'] == 1:
            count += 1
        if member['move'] == -1:
            count = 0
    return pd.DataFrame({'year': [year], 'budget': [result_budget], 'rise_count': [rise_count], 'fall_count': [fall_count], 'earnings rate': [(result_budget / budget) - 1]}).set_index('year')

# %%
m3_strategy_info(df_2021, 10000, 2021)
# Out:
#             budget  rise_count  fall_count  earnings rate
# year
# 2021  3.421880e-10       17191       15832           -1.0

# %%
m3_strategy_info(df_2020, 10000, 2020)
# Out:
#         budget  rise_count  fall_count  earnings rate
# year
# 2020  0.000017        9754       11558           -1.0

# %% [markdown]
# 각각 수익률 **-100%** 를 달성하였다. 말도 안되는 전략이었던 것 같다.
